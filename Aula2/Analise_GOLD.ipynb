# %% [markdown]
# ___
# # Atividade: Variáveis qualitativas com a PNAD (ALUNOS)
# ___
#
# ## Aula 02
#
#
# **Link úteis:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 16 – destacando para variáveis qualitativas.
# 2.	10 Minutes to Pandas: http://pandas.pydata.org/pandas-docs/stable/10min.html
# 3.	Essential Basic Functionality: http://pandas.pydata.org/pandas-docs/stable/basics.html
# 4.  Estude a aula `Aula02 Análise Exploratoria Variáveis Qualitativas-ALUNOS.ipynb`, o qual contém uma introdução ao Jupyter Notebook. A publicação dessa aula tem como objetivo auxiliá-lo, caso queira, no desenvolvimento dos seus próximos programas, como esta atividade.
#
# **Hoje:**
# 1.	Analisar variáveis qualitativas de forma uni e bivariadas utilizando tabelas de frequências e gráficos de barras e de pizza (ou setor).
# 2.  Trabalhar com a base de dados da PNAD 2013 - Pesquisa Nacional por Amostra de Domicílios
#
# **Próxima aula:**
# 1.	Leitura prévia necessária: Magalhães e Lima (7ª. Edição): pág. 9 a 17 – destacando para variáveis quantitativas; pág. 106 e 107 (Definição 4.1 e Exemplo 4.1).
#
# ___

# %% [markdown]
# ___
# ## <font color='blue'>PNAD 2013 – PESQUISA NACIONAL POR AMOSTRA DE DOMICÍLIOS</font>
#
# **Base de dados reduzida: ** `pes2013A.txt` (75 MB)
# [Acesse a base de dados aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/pes2013A.txt]
#
# **Dicionário das variáveis: ** `Dicionário de variáveis de pessoas - PNAD 2013.xlsx`
# [Acesse dicionário aqui: https://dl.dropboxusercontent.com/u/65763596/Aula02/Dicion%C3%A1rio%20de%20vari%C3%A1veis%20de%20pessoas%20-%20PNAD%202013.xls]
#
#
# Muitos especialistas na área de negócios dizem que empresários mais bem sucedidos são aqueles que fazem um planejamento antes de começar seu próprio negócio. Nessa visão, imagine que o Sr. Gold tenha como grande objetivo abrir uma nova faculdade e para isso deseja estudar o perfil do estudante que cursa ensino médio ou pré-vestibular e do que cursa ensino superior.
#
# Assuma que as variáveis de interesse a respeito dos estudantes sejam relativamente as mesmas de 2013 até o momento atual. Nesse caso, seja criativo para ajudar o Sr. Gold que deseja abrir seu negócio, mas não tem certeza sobre quais variáveis o interessam.
#
# Vocês podem ajudá-lo?!
#
# As variáveis a seguir devem fazer parte da sua análise:
#
# * V0302: sexo
# * V0404: cor ou raça
# * V6002: rede de ensino
# * V4802: nível de ensino e grupos de séries do ensino fundamental que frequentavam (todos os estudantes)
#
# ** Crie uma variável com região do indivíduo amostrado considerando a variável `UF` que define o estado e também trabalhe com essa nova variável em suas análises. **
#
# ** Escolha mais pelo menos DUAS variáveis qualitativas para completar sua análise!! **
#
# Faça uma análise exploratória apenas com as variáveis qualitativas com foco no objetivo do Sr. Gold.
#
# Sua análise deve conter pelo menos uma das seguintes visualizações:
#
# 1. Gráfico de colunas (bar) e setor (pie) com as frequências relativas cadas categorias das variáveis qualitativas.
# 2. Tabela cruzada entre pares de variaveis qualitativas. Montar o gráfico de colunas. Repetir o processo habilitando a opção "stacked=True".
#
#
# ___
#
#
#
# <font color='red'>
# Crie um repositório chamado CD em seu Github
# </font>
#
#
# Neste repositório, salve seu trabalho numa pasta chamada aula2
#
# Por exemplo, se seu login for *pikachu* o projeto vai estar na pasta:
#
# https://github.com/<font color=red>pikachu/CD/aula2</font>
#
#
#
# ## <font color='red'>Terça-feira (dia 16/08), no horário de atendimento da sua turma, deverá apresentar aos NINJAS!!</font>
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Martim\Dropbox\Insper\SegundoSemestre\CD\Aula2

# %%
dados = pd.read_table("pes2013A.txt", encoding="windows-1252", sep=" ")
dados.head()
# Out:
#    V0101  UF  V0102  V0103  V0301  V0302  V8005  V0404  V4011  V0412  ...    \
# 1   2013  11     15      3      1      4     42      2    5.0      2  ...
# 2   2013  11     15      4      1      4     64      8    7.0      2  ...
# 3   2013  11     15      4      2      4     13      4    0.0      2  ...
# 4   2013  11     15      5      1      2     23      8    0.0      2  ...
# 5   2013  11     15      5      2      4     19      8    0.0      2  ...
#
#    V4706  V4707  V4809  V4810  V4711  V4718  V4720  V4742  V4750  V4729
# 1    NaN    NaN    NaN    NaN    NaN    NaN  350.0  350.0  350.0    244
# 2    NaN    NaN    NaN    NaN    NaN    NaN  678.0  339.0  339.0    243
# 3    NaN    NaN    NaN    NaN    NaN    NaN    0.0  339.0  339.0    243
# 4    1.0    3.0    5.0    5.0    1.0  800.0  800.0  266.0  266.0    243
# 5    NaN    NaN    NaN    NaN    NaN    NaN    0.0  266.0  266.0    243
#
# [5 rows x 72 columns]

# %%
dados.dtypes
# Out:
# V0101         int64
# UF         category
# V0102         int64
# V0103         int64
# V0301         int64
# V0302      category
# V8005         int64
# V0404      category
# V4011       float64
# V0412         int64
# V0501         int64
# V0502       float64
# V5030       float64
# V0504       float64
# V0505       float64
# V5061       float64
# V5062       float64
# V5063       float64
# V5064       float64
# V5065       float64
# V0601      category
# V0602         int64
# V6002      category
# V6020       float64
# V6003       float64
# V0606       float64
# V6007       float64
# V0611       float64
# V06111      float64
# V061111     float64
#              ...
# V9043       float64
# V9044       float64
# V9045       float64
# V9046       float64
# V9047       float64
# V9048       float64
# V1091       float64
# V1092       float64
# V1101       float64
# V1141       float64
# V1142       float64
# V1151       float64
# V1152       float64
# V1153       float64
# ...

# %%
dados.UF = dados.UF.astype("category")
dados.UF.cat.categories = ("Rondônia",\
"Acre",\
"Amazonas",\
"Roraima",\
"Pará",\
"Amapá",\
"Tocantins",\
"Maranhão",\
"Piauí",\
"Ceará",\
"Rio Grande do Norte",\
"Paraíba",\
"Pernambuco",\
"Alagoas",\
"Sergipe",\
"Bahia",\
"Minas Gerais",\
"Espírito Santo",\
"Rio de Janeiro",\
"São Paulo",\
"Paraná",\
"Santa Catarina",\
"Rio Grande do Sul",\
"Mato Grosso do Sul",\
"Mato Grosso",\
"Goiás",\
"Distrito Federal")
dados.V0302 = dados.V0302.astype("category")
dados.V0302.cat.categories = ("Masculino","Feminino")
dados.V0404 = dados.V0404.astype("category")
dados.V0404.cat.categories = ("Indígena","Branca","Preta","Amarela","Parda","Sem Declaração")
dados.V6002 = dados.V6002.astype("category")
dados.V6002.cat.categories = ("Pública","Privada")
dados.V4802 = dados.V4802.astype("category")
dados.V4802.cat.categories = ("Maternal, jardim de infância etc.", "Classe de alfabetização", "Alfabetização de adultos",\
"1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos",\
"5ª a 8ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos",\
"1ª série do ensino fundamental regular em 9 anos",\
"2ª a 5ª séries do ensino fundamental regular em 9 anos",\
"6ª a 9ª séries do ensino fundamental regular em 9 anos",\
"Educação de jovens e adultos não seriado do ensino fundamental",\
"Ensino médio, inclusive pré-vestibular",\
"Superior, inclusive mestrado ou doutorado")
dados.V0601 = dados.V0601.astype("category")
dados.V0601.cat.categories = ("Sim","Não")
dados.V9001 = dados.V9001.astype("category")
dados.V9001.cat.categories = ("Sim","Não")

slicedtable = dados.loc[:, ("UF","V0302","V0404","V6002", "V4802", "V0601", "V9001")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b460b9581f01> in <module>()
# ----> 1 dados.UF = dados.UF.astype("category")
#       2 dados.UF.cat.categories = ("Rondônia","Acre","Amazonas","Roraima","Pará","Amapá","Tocantins","Maranhão","Piauí","Ceará","Rio Grande do Norte","Paraíba","Pernambuco","Alagoas","Sergipe","Bahia","Minas Gerais","Espírito Santo","Rio de Janeiro","São Paulo","Paraná","Santa Catarina","Rio Grande do Sul","Mato Grosso do Sul","Mato Grosso","Goiás","Distrito Federal")
#       3 dados.V0302 = dados.V0302.astype("category")
#       4 dados.V0302.cat.categories = ("Masculino","Feminino")
#       5 dados.V0404 = dados.V0404.astype("category")
#
# NameError: name 'dados' is not defined

# %%
slicedtable
# Out:
#                       UF      V0302   V0404    V6002  \
# 1               Rondônia   Feminino  Branca      NaN
# 2               Rondônia   Feminino   Parda      NaN
# 3               Rondônia   Feminino   Preta  Pública
# 4               Rondônia  Masculino   Parda      NaN
# 5               Rondônia   Feminino   Parda  Privada
# 6               Rondônia   Feminino   Parda  Privada
# 7               Rondônia  Masculino   Preta      NaN
# 8               Rondônia   Feminino  Branca      NaN
# 9               Rondônia  Masculino   Parda      NaN
# 10              Rondônia   Feminino  Branca      NaN
# 11              Rondônia   Feminino  Branca  Pública
# 12              Rondônia  Masculino  Branca      NaN
# 13              Rondônia   Feminino  Branca      NaN
# 14              Rondônia  Masculino  Branca  Privada
# 15              Rondônia   Feminino  Branca      NaN
# 16              Rondônia   Feminino  Branca  Privada
# 17              Rondônia  Masculino  Branca      NaN
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Tabelas Univariadas

# %%
dados.dtypes
# Out:
# V0101         int64
# UF         category
# V0102         int64
# V0103         int64
# V0301         int64
# V0302      category
# V8005         int64
# V0404      category
# V4011       float64
# V0412         int64
# V0501         int64
# V0502       float64
# V5030       float64
# V0504       float64
# V0505       float64
# V5061       float64
# V5062       float64
# V5063       float64
# V5064       float64
# V5065       float64
# V0601      category
# V0602         int64
# V6002      category
# V6020       float64
# V6003       float64
# V0606       float64
# V6007       float64
# V0611       float64
# V06111      float64
# V061111     float64
#              ...
# V9043       float64
# V9044       float64
# V9045       float64
# V9046       float64
# V9047       float64
# V9048       float64
# V1091       float64
# V1092       float64
# V1101       float64
# V1141       float64
# V1142       float64
# V1151       float64
# V1152       float64
# V1153       float64
# ...

# %%
#Tabelas univariadas
n=dados.shape[0] #Número de linhas

#Estado (UF)
print("Estado a que pertence")
table0 = (dados.UF.value_counts()/n*100).round(decimals=1).reindex(["Rondônia",\
"Acre",\
"Amazonas",\
"Roraima",\
"Pará",\
"Amapá",\
"Tocantins",\
"Maranhão",\
"Piauí",\
"Ceará",\
"Rio Grande do Norte",\
"Paraíba",\
"Pernambuco",\
"Alagoas",\
"Sergipe",\
"Bahia",\
"Minas Gerais",\
"Espírito Santo",\
"Rio de Janeiro",\
"São Paulo",\
"Paraná",\
"Santa Catarina",\
"Rio Grande do Sul",\
"Mato Grosso do Sul",\
"Mato Grosso",\
"Goiás",\
"Distrito Federal"])
print(table0,'\n')

#Sexo (V0302)
print('Porcentagem de Pessoas por Sexo:')
table1 = (dados.V0302.value_counts()/n*100).round(decimals=1).reindex(["Masculino", "Feminino"])
print(table1,'\n')

#Raça (V0404)
print('Porcentagem de Pessoas por Raça:')
table2 = (dados.V0404.value_counts()/n*100).round(decimals=1).reindex(["Indígena","Branca","Preta","Amarela","Parda","Sem Declaração"])
print(table2,'\n')

#Rede de ensino (V6002)
print('Porcentagem de Pessoas por Rede de Ensino:')
table3 = (dados.V6002.value_counts()/n*100).round(decimals=1).reindex(["Pública", "Privada"])
print(table3,'\n')

#Nível de ensino e grupos de séries do ensino fundamental que frequentavam (Todos os estudantes - V4802)
print('Porcentagem de Pessoas por Raça:')
table4 = (dados.V4802.value_counts()/n*100).round(decimals=1).reindex(["Maternal, jardim de infância etc.",\
"Classe de alfabetização",\
"Alfabetização de adultos",\
"1ª a 4ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos",\
"5ª a 8ª séries do ensino fundamental regular em 8 anos ou de educação de jovens e adultos",\
"1ª série do ensino fundamental regular em 9 anos",\
"2ª a 5ª séries do ensino fundamental regular em 9 anos",\
"6ª a 9ª séries do ensino fundamental regular em 9 anos",\
"Educação de jovens e adultos não seriado do ensino fundamental",\
"Ensino médio, inclusive pré-vestibular",\
"Superior, inclusive mestrado ou doutorado"])
print(table4,'\n')

#Sabe ler e escrever (V0601)
print('Porcentagem de pessoas alfabetizadas:')
table5 = (dados.V0601.value_counts()/n*100).round(decimals=1).reindex(["Sim", "Não"])
print(table5,'\n')

#Trabalha (V9001)
print('Porcentagem de pessoas que trabalham:')
table6 = (dados.V9001.value_counts()/n*100).round(decimals=1).reindex(["Sim", "Não"])
print(table6,'\n')
# Out:
# Estado a que pertence
# Rondônia                2.0
# Acre                    1.2
# Amazonas                3.6
# Roraima                 0.8
# Pará                    6.2
# Amapá                   0.8
# Tocantins               1.8
# Maranhão                2.6
# Piauí                   1.5
# Ceará                   5.3
# Rio Grande do Norte     1.4
# Paraíba                 1.7
# Pernambuco              5.7
# Alagoas                 1.5
# Sergipe                 1.7
# Bahia                   7.5
# Minas Gerais            9.1
# Espírito Santo          1.9
# Rio de Janeiro          7.1
# São Paulo              10.9
# Paraná                  5.3
# Santa Catarina          2.7
# Rio Grande do Sul       7.5
# Mato Grosso do Sul      1.7
# Mato Grosso             2.0
# Goiás                   4.1
# Distrito Federal        2.6
# Name: UF, dtype: float64
#
# Porcentagem de Pessoas por Sexo:
# Masculino    48.6
# Feminino     51.4
# Name: V0302, dtype: float64
#
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Gráficos de Barras

# %%
#Gráfico de Barras -> Porcentagem de Pessoas por Estado
plot = table0.plot(kind='bar',title='Estado',figsize=(6,6))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Estados')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas por Sexo
plot = table1.plot(kind='bar',title='Sexo',figsize=(6,6),color=('b','r'))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Sexos')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas por Raça
plot = table2.plot(kind='bar',title='Frequência de Raças',figsize=(6,6),color=('y','r','k','w','c','b'))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Raça')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas por Rede de Ensino
plot = table3.plot(kind='bar',title='Rede de Ensino',figsize=(6,6), color = ('b','g','r'))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Rede de Ensino')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas por Tipo de Ensino
plot = table4.plot(kind='bar',title='Tipo de Ensino',figsize=(6,6), color = ('b','g','r'))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Tipo de Ensino')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas alfabetizadas
plot = table5.plot(kind='bar',title='Sabem ler e escrever',figsize=(6,6),color=('b','r'))
plt.ylabel('Pessoas (em %)')

# %%
#Gráfico de Barras -> Porcentagem de Pessoas que trabalham
plot = table6.plot(kind='bar',title='Exercem atividade remunerada',figsize=(6,6),color=('b','r'))
plt.ylabel('Pessoas (em %)')
plt.xlabel('Trabalham')

# %% [markdown]
# ##

# %% [markdown]
# ##  Gráfico de Pizza

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas por Sexo
pizza1 = table1.plot(kind='pie',title='Sexo',autopct='%.1f',figsize=(9, 9))

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas por Raça
pizza2 = table2.plot(kind='pie',title='Frequência de Raças',autopct='%.1f',figsize=(9, 9),colors=('y','r','k','w','c','b'))

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas por Rede de Ensino
pizza1 = table3.plot(kind='pie',title='Rede de Ensino',autopct='%.1f',figsize=(9, 9))

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas por Tipo de Ensino
pizza1 = table4.plot(kind='pie',title='Tipo de Ensino',autopct='%.1f',figsize=(9, 9))

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas que sabem ler e escrever
pizza1 = table5.plot(kind='pie',title='Sabem ler e escrever',autopct='%.1f',figsize=(9, 9))

# %%
#Gráfico de Pizza -> Porcentagem de Pessoas que trabalham
pizza1 = table6.plot(kind='pie',title='Trabalham',autopct='%.1f',figsize=(9, 9))

# %% [markdown]
# ##

# %% [markdown]
# ## Tabelas cruzadas entre variáveis qualitativas

# %%
#Função que divide cada valor da tabela cruzada pelo total da última linha (quando axis=0) ou da última coluna (quando axis=1)
#Retorna tabela cruzada com valores sem casa decimais
#https://www.analyticsvidhya.com/blog/2016/01/12-pandas-techniques-python-data-manipulation/
def percConvert(tab):
  return (tab/float(tab[-1])*100).round(decimals=0)

# %%
#Tabela cruzada dos estados pelos niveis de ensino
UFN = pd.crosstab(dados.UF, dados.V4802, margins=True,rownames=['ESTADO'], colnames=['NIVEL DE ENSINO'])
slicedUFN = UFN.iloc[:,(9,10)]
slicedUFN
# Out:
# NIVEL DE ENSINO      Ensino médio, inclusive pré-vestibular  \
# ESTADO
# Rondônia                                                373
# Acre                                                    241
# Amazonas                                                738
# Roraima                                                 150
# Pará                                                   1245
# Amapá                                                   169
# Tocantins                                               400
# Maranhão                                                553
# Piauí                                                   279
# Ceará                                                   949
# Rio Grande do Norte                                     216
# Paraíba                                                 258
# Pernambuco                                              997
# Alagoas                                                 226
# ...

# %%
UFN1 = (UFN/len(dados)*100).round(decimals=2)
UFN1 = UFN1.iloc[:,(9,10,11)]
UFN1
# Out:
# NIVEL DE ENSINO      Ensino médio, inclusive pré-vestibular  \
# ESTADO
# Rondônia                                               0.10
# Acre                                                   0.07
# Amazonas                                               0.20
# Roraima                                                0.04
# Pará                                                   0.34
# Amapá                                                  0.05
# Tocantins                                              0.11
# Maranhão                                               0.15
# Piauí                                                  0.08
# Ceará                                                  0.26
# Rio Grande do Norte                                    0.06
# Paraíba                                                0.07
# Pernambuco                                             0.27
# Alagoas                                                0.06
# ...

# %%
UFN1 = (UFN/len(dados)*100).round(decimals=2)
UFN1 = UFN1.iloc[0:27,(9,10)]
plot = UFN1.plot(kind='bar', stacked=True,title='Estados por Ensino',figsize=(9,9))
plt.ylabel('Freq.Relativa (em %)')
plot

# %%
UFN1 = (UFN/len(dados)*100).round(decimals=2)
UFN1 = UFN1.iloc[0:27,(9,10)]
plot = UFN1.plot(kind='bar', stacked=False,title='Estados por Ensino',figsize=(9,9))
plt.ylabel('Freq.Relativa (em %)')
plot

# %%
UFT = pd.crosstab(dados.UF, dados.V6002, margins=True,rownames=['ESTADO'], colnames=['TIPO DE ENSINO'])
slicedUFT = UFT.iloc[:27,:2]
slicedUFT = (UFT/len(dados)*100).round(decimals=2)
slicedUFT
# Out:
# TIPO DE ENSINO       Pública  Privada    All
# ESTADO
# Rondônia                0.49     0.08   0.57
# Acre                    0.40     0.04   0.44
# Amazonas                1.04     0.23   1.27
# Roraima                 0.21     0.04   0.25
# Pará                    1.64     0.34   1.98
# Amapá                   0.23     0.05   0.29
# Tocantins               0.48     0.08   0.56
# Maranhão                0.78     0.11   0.89
# Piauí                   0.41     0.09   0.50
# Ceará                   1.14     0.41   1.55
# Rio Grande do Norte     0.31     0.10   0.41
# Paraíba                 0.37     0.14   0.50
# Pernambuco              1.06     0.51   1.57
# Alagoas                 0.37     0.10   0.47
# Sergipe                 0.39     0.14   0.52
# Bahia                   1.61     0.62   2.23
# Minas Gerais            1.88     0.55   2.43
# Espírito Santo          0.39     0.10   0.50
# Rio de Janeiro          1.18     0.62   1.80
# São Paulo               2.04     0.73   2.78
# ...

# %%
UFT1 = (UFT/len(dados)*100).round(decimals=2)
UFT1 = UFT1.iloc[0:27,(1,0)]
plot = UFT1.plot(kind='bar', stacked=True,title='Público x Privado',figsize=(9,9))
plt.ylabel('Freq.Relativa (em %)')
plot

# %%
UFT1 = (UFT/len(dados)*100).round(decimals=2)
UFT1 = UFT1.iloc[0:27,(1,0)]
plot = UFT1.plot(kind='bar', stacked=False,title='Público x Privado',figsize=(8,8))
plt.ylabel('Freq.Relativa (em %)')
plot

# %% [markdown]
# ##

# %% [markdown]
# # Conclusões

# %% [markdown]
#    Pelo gráfico de Nível de Ensino pelos Estados da Federação, observamos que nos estados de São Paulo, Minas Gerais e Bahia, há uma maior frequência relativa de pessoas nos níveis de ensino médio e ensino superior. Além disso, são os que apresentam maior frequência relativa de pessoas no ensino privado, comparando-se com as outras, apesar de possuírem o ensino público como predominante.
#    Desta forma, concluímos que o Sr. Gold deve investir em São Paulo, Minas Gerais ou Bahia para que sua faculdade gere lucros, uma vez que nesses estados há um  maior número de pessoas que necessitam desse serviço, dado que muitas são do Ensino Médio.
#
#
# Filipe Foschini Borba e Martim Ferreira José

# %%
UFT1 = (UFT/len(dados)*100).round(decimals=2)
UFT1 = UFT1.iloc[0:27,(1,0)]
plot = UFT1.plot(kind='bar', stacked=False,title='Público x Privado',figsize=(9,9))
plt.ylabel('Freq.Relativa (em %)')
plot

# %%
UFN1 = (UFN/len(dados)*100).round(decimals=2)
UFN1 = UFN1.iloc[0:27,(9,10)]
plot = UFN1.plot(kind='bar', stacked=False,title='Estados por Ensino',figsize=(9,9))
plt.ylabel('Freq.Relativa (em %)')
plot

# %%
dados = pd.read_table("pes2013A.txt", encoding="windows-1252", sep=" ")

# %%
dados["REGIÕES"] = dados.UF
dados.REGIÕES[(dados.UF > 10) & (dados.UF < 18)] = "Norte"
dados.REGIÕES[(dados.UF >=41) & (dados.UF <= 43)] = "Sul"
dados.REGIÕES[(dados.UF >=21) & (dados.UF <= 29)] = "Nordeste"
dados.REGIÕES[(dados.UF >=50) & (dados.UF <= 53)] = "CentroOeste"
dados.REGIÕES[(dados.UF >=31) & (dados.UF <= 35)] = "Sudeste"
#dados["REGIÕES"].value_counts()
#dados["REGIÕES"]
df = pd.DataFrame(dados["REGIÕES"].value_counts())
df
# Out:
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
Norte = dados[(dados.UF > 10) & (dados.UF < 18)].iloc[:,1:2]
Sul = dados[(dados.UF >=41) & (dados.UF <= 43)].iloc[:,1:2]
Nordeste = dados[(dados.UF >=21) & (dados.UF <= 29)].iloc[:,1:2]
CentroOeste = dados[(dados.UF >=50) & (dados.UF <= 53)].iloc[:,1:2]
Sudeste = dados[(dados.UF >=31) & (dados.UF <= 35)].iloc[:,1:2]

somat = dados.UF.sum()

NR = (Norte.sum()/somat)*100
SR = (Sul.sum()/somat)*100
NordR = (Nordeste.sum()/somat)*100
SudR = (Sudeste.sum()/somat)*100
COR = (CentroOeste.sum()/somat)*100

lista_dados_regiao = [NR, SR, NordR, SudR, COR]
labelsR = ["Norte", 'Sul', "Nordeste", "Sudeste", "Centro Oeste"]
plt.pie(lista_dados_regiao, labels = labelsR, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x236000010b8>,
# ...
#   <matplotlib.text.Text at 0x2360001d4e0>])

# %% [markdown]
# # Variáveis Quantitativas

# %% [markdown]
# ##

# %%
import numpy as np

# %%
#Idade (V8005)
idades = np.arange(10,100,4)
idadesp = dados[(dados.UF == 35)].V8005
plot = idadesp.plot.hist(bins = idades, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Idade (anos)")

# %%
#Idade SP
plot = idadesp.plot(kind='box')
idadesp.describe()
# Out:
# count    39531.000000
# mean        34.748704
# std         20.942655
# min          0.000000
# 25%         18.000000
# 50%         33.000000
# 75%         50.000000
# max        107.000000
# Name: V8005, dtype: float64

# %%
#Idade  MG
idades = np.arange(10,100,4)
idademg = dados[(dados.UF == 31)].V8005
plot = idademg.plot.hist(bins = idades, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Idade (anos)")

# %%
#Idade MG
plot = idademg.plot(kind='box')
idademg.describe()
# Out:
# count    33137.000000
# mean        34.229502
# std         20.898683
# min          0.000000
# 25%         17.000000
# 50%         33.000000
# 75%         50.000000
# max        104.000000
# Name: V8005, dtype: float64

# %%
#Idade BA
idades = np.arange(10,100,4)
idadeba = dados[(dados.UF == 29)].V8005
plot = idadeba.plot.hist(bins = idades, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Idade (anos)")

# %%
#Idade MG
plot = idadeba.plot(kind='box')
idadeba.describe()
# Out:
# count    27247.000000
# mean        32.629207
# std         20.787898
# min          0.000000
# 25%         15.000000
# 50%         31.000000
# 75%         47.000000
# max        105.000000
# Name: V8005, dtype: float64

# %%
#Horas trabalhadas por semana
intervalo = np.arange(0,6,1)
hrs_trab_sem = dados["V4707"]
hrstrab = pd.cut(hrs_trab_sem, intervalo)
hrstrab.value_counts()
hrs_trab_sem.hist(bins = intervalo)

# %%
#Renda em SP(V4720)
faixas = np.arange(500,5000,100)
rendasp = dados[(dados.UF == 35) & (dados.V4720 != 999999999999)].V4720

plot = rendasp.plot.hist(bins = faixas, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Renda per capta")

# %%
#Renda em MG(V4720)
faixas = np.arange(500,5000,100)
rendamg = dados[(dados.UF == 31) & (dados.V4720 != 999999999999)].V4720

plot = rendamg.plot.hist(bins = faixas, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Renda per capta")

# %%
#Renda em BA(V4720)
faixas = np.arange(500,5000,100)
rendaba = dados[(dados.UF == 29) & (dados.V4720 != 999999999999)].V4720

plot = rendaba.plot.hist(bins = faixas, normed = 1)
plt.ylabel("Frequência Relativa (%)")
plt.xlabel("Renda per capta")

# %%
#renda SP
rendasp.plot(kind='box')
rendasp.describe()
# Out:
# C:\Users\Martim\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count     32959.000000
# mean       1386.062047
# std        2768.184704
# min           0.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max      180000.000000
# Name: V4720, dtype: float64

# %%
#renda MG
rendamg.plot(kind='box')
rendamg.describe()
# Out:
# C:\Users\Martim\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count     28504.000000
# mean       1143.026873
# std        2228.276926
# min           0.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max      130000.000000
# Name: V4720, dtype: float64

# %%
#renda BA
rendaba.plot(kind='box')
rendaba.describe()
# Out:
# C:\Users\Martim\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count     22739.000000
# mean        887.288491
# std        2491.600290
# min           0.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max      160000.000000
# Name: V4720, dtype: float64

# %%
dados["REGIOES"] = dados.UF
dados.REGIOES[(dados.UF > 10) & (dados.UF < 18)] = "Norte"
dados.REGIOES[(dados.UF >=41) & (dados.UF <= 43)] = "Sul"
dados.REGIOES[(dados.UF >=21) & (dados.UF <= 29)] = "Nordeste"
dados.REGIOES[(dados.UF >=50) & (dados.UF <= 53)] = "CentroOeste"
dados.REGIOES[(dados.UF >=31) & (dados.UF <= 35)] = "Sudeste"
#dados["REGIÕES"].value_counts()
#dados["REGIÕES"]
df = pd.DataFrame(dados["REGIOES"])
# Out:
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Martim\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
regioes = dados
birl = regioes[(regioes.V4742 != 999999999999)]
birl.boxplot(column="V4742", by = "REGIOES", figsize= (5,5))
plt.axis([0,6,0,2700])
# Out:
# [0, 6, 0, 2700]

# %%
dados.boxplot(column="V8005", by = "REGIOES", figsize= (5,5))

# %% [markdown]
# -----
#
# ## SEGUNDA CONCLUSÃO
#
# Na nossa primeira conclusão utilizando apenas variáveis qualitativas, chegamos à conclusão de que a região Sudeste seria a
# mais atrante para os negócios do Sr. Gold (mais especificamente, São Paulo e Minas Gerais, além de Bahia, apesar de não ser
# da região Sudeste).
#
# Utilizando agora variáveis quantitativas, pudemos perceber que o primeiro quartil de idade, dos Estados de MG, SP e BA são respectivamente: 15, 18, 17. Apesar do Norte e Nordeste serem as regiões mais novas, elas também são as mais pobres, a maioria das pessoas ganham abaixo de 1000 reais per capita no núcleo familiar.
#
# A região que o Mr. Gold deve focar seu interesse continua sendo a Sudeste, onde há mais renda por integrante da familia, e também onde há muitos jovens na "faixa etária de faculdade", isso sendo observado por SP, onde o primeiro e segundo quartil são 18 e 33 anos respectivamente.
